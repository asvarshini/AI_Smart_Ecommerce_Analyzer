# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load e-commerce datasets for orders, products, and order 
df_orders = pd.read_csv(r"D:\AI_Smart_Ecommerce_Analyzer\data\00_raw\olist_orders_dataset.csv")
df_items = pd.read_csv(r"D:\AI_Smart_Ecommerce_Analyzer\data\00_raw\olist_order_items_dataset.csv")
df_products = pd.read_csv(r"D:\AI_Smart_Ecommerce_Analyzer\data\00_raw\olist_products_dataset.csv")

# %%
# Inspect column datatypes and missing values
df_orders.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
df_items.isnull().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
df_products.isnull().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
#checking weather duplicates rows exist in the dataset
df_orders.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_items.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_products.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Convert purchase timestamp from string to datetime format
df_orders['order_purchase_timestamp'] = pd.to_datetime(df_orders['order_purchase_timestamp'])

# %%
# Group orders by month to analyze purchase trend over time
orders_trend = df_orders.groupby(
    df_orders['order_purchase_timestamp'].dt.to_period('M')
).size()
orders_trend
# Out:
# order_purchase_timestamp
# 2016-09       4
# 2016-10     324
# 2016-12       1
# 2017-01     800
# 2017-02    1780
# 2017-03    2682
# 2017-04    2404
# 2017-05    3700
# 2017-06    3245
# 2017-07    4026
# 2017-08    4331
# 2017-09    4285
# 2017-10    4631
# 2017-11    7544
# 2017-12    5673
# 2018-01    7269
# 2018-02    6728
# 2018-03    7211
# 2018-04    6939
# 2018-05    6873
# 2018-06    6167
# 2018-07    6292
# 2018-08    6512
# 2018-09      16
# 2018-10       4
# Freq: M, dtype: int64

# %%
orders_trend.plot(marker='o', figsize=(10,5), title='Monthly Order Trend')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
# Merge order items with product details to access category information
df_merged = pd.merge(df_items, df_products, on='product_id')
df_merged
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
# Calculate top-selling product categories
category_counts = df_merged['product_category_name'].value_counts().head(10)
category_counts
# Out:
# product_category_name
# cama_mesa_banho           11115
# beleza_saude               9670
# esporte_lazer              8641
# moveis_decoracao           8334
# informatica_acessorios     7827
# utilidades_domesticas      6964
# relogios_presentes         5991
# telefonia                  4545
# ferramentas_jardim         4347
# automotivo                 4235
# Name: count, dtype: int64

# %%
#Visualize most popular product categories
category_counts.plot(kind='bar')
plt.title("Top 10 Product Categories")
plt.xlabel("Category")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %%
df_items['price'].hist(bins=5)
plt.title('price Distribution')
plt.xlabel("price")
plt.ylabel("Frequency")
plt.show()

# %%
# Count order statuses
status_counts = df_orders['order_status'].value_counts()
status_counts
# Out:
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: count, dtype: int64

# %%
# Plot order status distribution

status_counts.plot(kind='bar')

plt.title("Order Status Distribution")
plt.xlabel("Order Status")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %%
#Customer Geography Analysis

# %%
df_customers=pd.read_csv(r"D:\AI_Smart_Ecommerce_Analyzer\data\00_raw\olist_customers_dataset.csv")
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
mer_geo=pd.merge(df_orders,df_customers,on='customer_id')
mer_geo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
#  8   customer_unique_id             99441 non-null  object
#  9   customer_zip_code_prefix       99441 non-null  int64
#  10  customer_city                  99441 non-null  object
#  11  customer_state                 99441 non-null  object
# ...

# %%
state_count=mer_geo['customer_state'].value_counts().head()
state_count
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# Name: count, dtype: int64

# %%
# Visualize top customer states

state_count.plot(kind='bar')
plt.title("Top Customer States")
plt.xlabel("State")
plt.ylabel("Number of Customers")
plt.xticks(rotation=45)
plt.show()

# %%
#Customer Purchase Behavior Analysis

# %%
# Count number of orders per customer
customer_orders = mer_geo.groupby('customer_unique_id')['order_id'].count()

# %%
# Visualize customer purchase behavior
customer_orders.hist(bins=30)
plt.title("Customer Purchase Frequency")
plt.xlabel("Orders Per Customer")
plt.ylabel("Number of Customers")
plt.show()

# %%
#Analyze revenue treand

# %%
df_revenue=pd.merge(df_orders,df_items,on='order_id')

# %%
df_revenue['order_purchase_timestamp'] = pd.to_datetime(df_revenue['order_purchase_timestamp'])
monthly_revenue = df_revenue.groupby(
    df_revenue['order_purchase_timestamp'].dt.to_period('M')
)['price'].sum()

# %%
monthly_revenue.plot()

plt.title("Monthly Revenue Trend")
plt.xlabel("Month")
plt.ylabel("Revenue")
plt.show()

# %%
#Analyze revenue contribution across product categories

# %%
df_category_revenue = pd.merge(df_items, df_products, on='product_id')

# %%
category_revenue = df_category_revenue.groupby(
    'product_category_name'
)['price'].sum().sort_values(ascending=False).head(10)

# %%
category_revenue.plot(kind='bar')

plt.title("Top Revenue Generating Categories")
plt.xlabel("Category")
plt.ylabel("Revenue")
plt.xticks(rotation=45)
plt.show()
